# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ef88efe5-ea27-45ed-beb8-8fa56ce8dde4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef88efe5-ea27-45ed-beb8-8fa56ce8dde4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Пальмовое масло data.xlsx to Пальмовое масло data (4).xlsx

# %%
xls = pd.ExcelFile('Пальмовое масло data (4).xlsx')
df1 = pd.read_excel(xls, '4')
#df3 = pd.read_excel(xls, '3')

# %%
df1.head()
# Out:
#    Unnamed: 0  новообразования  ...  болезни мочеполовой системы  Пальмовое масло
# 0        2012             11.6  ...                         49.6         659.1591
# 1        2013             11.4  ...                         49.8         746.5989
# 2        2014             11.6  ...                         49.0         706.3245
# 3        2015             11.4  ...                         46.4         888.8692
# 4        2016             11.4  ...                         45.6         885.1707
#
# [5 rows x 11 columns]

# %%
df1.info
# Out:
# <bound method DataFrame.info of    Unnamed: 0  новообразования  ...  болезни мочеполовой системы  Пальмовое масло
# 0        2012             11.6  ...                         49.6         659.1591
# 1        2013             11.4  ...                         49.8         746.5989
# 2        2014             11.6  ...                         49.0         706.3245
# 3        2015             11.4  ...                         46.4         888.8692
# 4        2016             11.4  ...                         45.6         885.1707
# 5        2017             11.4  ...                         44.8         891.6361
# 6        2018             11.6  ...                         44.8        1060.1401
# 7        2019             11.9  ...                         44.5        1060.9322
#
# [8 rows x 11 columns]>

# %%
import openpyxl

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.heatmap(df1.corr(),cmap="YlGnBu",annot=True)
plt.show()

# %%
df=df1.drop(columns=['Unnamed: 0'])

# %%
sns.heatmap(df.corr(),cmap="YlGnBu",annot=True)
plt.show()
